# %% [markdown]
# # dictionary

# %%
#1. Dict is not indaxable
#2. Dict stores the data in Key value pair
#3. EMpty dic can be created using {}, dict()

# %%
a={}
type(a)
# Out:
# dict

# %%
dict()
# Out:
# {}

# %%
c={"id":12,"name":"sumit","age":21}
type(c)
# Out:
# dict

# %%
dir(c)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
c.values()
# Out:
# dict_values([12, 'sumit', 21])

# %%
c.copy()
# Out:
# {'id': 12, 'name': 'sumit', 'age': 21}

# %%
c.keys()
# Out:
# dict_keys(['id', 'name', 'age'])

# %%
data={"ids":[1,2,3,4,5],"names":["amol","kiran","atharv","sai","prabhat"],"age":[21,22,32,44,22]}             #for multiple key and values

# %%
data
# Out:
# {'ids': [1, 2, 3, 4, 5],
#  'names': ['amol', 'kiran', 'atharv', 'sai', 'prabhat'],
#  'age': [21, 22, 32, 44, 22]}

# %%
c.pop("id")         #remove the attribute and values with showing
# Out:
# 12

# %%
c
# Out:
# {'name': 'sumit', 'age': 21}

# %%
c.popitem()
# Out:
# ('age', 21)

# %%
c
# Out:
# {'name': 'sumit'}

# %%
c.setdefault("name")
# Out:
# 'sumit'

# %%
c
# Out:
# {'name': 'sumit'}

# %%
c.update({"id": 12})        # Correct way to update with a dictionary

# %%
# The error 'AttributeError: 'dict' object has no attribute '__dict__'' occurs because
# Python dictionary objects do not have a '__dict__' attribute.
# This attribute is typically found on instances of user-defined classes to store their attributes.
# Dictionaries, being built-in types, manage their attributes internally.

# If you wanted to inspect the methods and attributes of the dictionary, you should use dir(c).
# If you wanted to view the contents of the dictionary, simply 'c' would display it.

dir(c)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
c.get("id")               #get the keys
# Out:
# 12

# %%
c
# Out:
# {'name': 'sumit', 'id': 12}

# %%
data["names"][2]              #for give the index with slicing
# Out:
# 'atharv'

# %%
data
# Out:
# {'ids': [1, 2, 3, 4, 5],
#  'names': ['amol', 'kiran', 'atharv', 'sai', 'prabhat'],
#  'age': [21, 22, 32, 44, 22]}

# %% [markdown]
# # range

# %%
#range(start,end,step) here end willl be end-1
range(1,9)
# Out:
# range(1, 9)

# %%
for i in range(1,9,1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for i in range(5,1,-1):
  print(i)
# Out:
# 5
# 4
# 3
# 2
