# %% [markdown]
# # LIST

# %%
# Empty list
a = list()

# %%
#empty list
b = []

# %%
type(b)         #type of list
# Out:
# list

# %%
len(b)           #length of the list
# Out:
# 0

# %%
number=[22,33,44,555,6666,77]

# %%
dir(number)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
number.append(12)         #add element in last of the list element

# %%
number
# Out:
# [22, 33, 44, 555, 6666, 77, 12]

# %%
number.clear()            #clear the list

# %%
number
# Out:
# []

# %%
number.copy()       #copy the list
# Out:
# []

# %%
number
# Out:
# []

# %%
number=[1,2,3,4,5,56,3]             #count of the element

# %%
number.count(3)
# Out:
# 2

# %%
number.pop()                  #pop the last element and they will display first without run
# Out:
# 3

# %%
number
# Out:
# [1, 2, 3, 4, 5, 56]

# %%
number.extend([11,22,33])       #add element in the first list

# %%
number
# Out:
# [1, 2, 3, 4, 5, 56, 11, 22, 33]

# %%
number.index(22)          #index will be show
# Out:
# 7

# %%
number.insert(2,33)          #insert function is used to add in the your choice of index   #(index_no,value )

# %%
number
# Out:
# [1, 2, 33, 3, 4, 5, 56, 11, 22, 33]

# %%
number.reverse()      #reverse the list

# %%
number
# Out:
# [33, 22, 11, 56, 5, 4, 3, 33, 2, 1]

# %%
number[::-1]
# Out:
# [1, 2, 33, 3, 4, 5, 56, 11, 22, 33]

# %%
number.sort(reverse=True)            #sorting the element in disending order

# %%
number
# Out:
# [56, 33, 33, 22, 11, 5, 4, 3, 2, 1]

# %%
number.sort(reverse=False)    #asending order

# %%
number
# Out:
# [1, 2, 3, 4, 5, 11, 22, 33, 33, 56]

# %%
  #que=output is 456 how to show with use of slicing

g= [22,33,44,55,66,[1,2,3,4,5,[123,456,789]]]

# %%
g[5][5][1]
# Out:
# 456

# %% [markdown]
# # tuple

# %%
a = tuple()

# %%
type(a)
# Out:
# tuple

# %%
b = (1)
type(b)
# Out:
# int

# %%
b = (1,)
type(b)
# Out:
# tuple

# %%
t=1,2,3,4,3,3,3,3,
type(t)
# Out:
# tuple

# %%
dir(t)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
t.count(3)          #count of element
# Out:
# 5

# %%
t.index(1)          #index of element
# Out:
# 0

# %% [markdown]
# # Set

# %% [markdown]
# 1. s = set()
# 2. s = {} We can not use this to create empty set it is empty dictionary.
# 3. It is not indexable.
# 4. Elements are not having any position in set.
# 5. It does not allow duplicate records.
# 6. By default set is mutable
# 7. We can convert it into immutable using frozenset

# %%
s=set()

# %%
type(s)
# Out:
# set

# %%
a={32,55,34,556,66,3434,845}

# %%
type(a)
# Out:
# set

# %%
a                       #asending order
# Out:
# {32, 34, 55, 66, 556, 845, 3434}

# %%
a = [1,2,3,2,2,4,1,5]               #set is mutable so
a = set(a)
a = list(a)
a
# Out:
# [1, 2, 3, 4, 5]

# %%
dir(s)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
w={11,22,33,"sumit",1515}

# %%
type(w)
# Out:
# set

# %%
w.add("kiran")        #for add the element

# %%
w
# Out:
# {11, 1515, 22, 33, 'kiran', 'sumit'}

# %%
p={1,2,3,4}
q={4,5,6,7}

# %%
p.union(q)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
p.intersection(q)
# Out:
# {4}

# %%
p.issubset(q)
# Out:
# False

# %%
q
p
# Out:
# {1, 2, 3, 4}

# %%
p.pop()
# Out:
# 1

# %%
p
# Out:
# {2, 3, 4}

# %%
p.add(1)

# %%
p
# Out:
# {1, 2, 3, 4}

# %%
p.discard(3)       #3 will be remove
p
# Out:
# {1, 2, 4}

# %%
p.update()

# %%
p
# Out:
# {1, 2, 4}

# %%
p.remove(2)               #remove the element

# %%
p
# Out:
# {1, 4}

# %%
p
# Out:
# {1, 4}

# %%
q
# Out:
# {4, 5, 6, 7}

# %%
p.difference(q)
# Out:
# {1}

# %%
p.add(2)

# %%
p
# Out:
# {1, 2, 4}

# %%
p.symmetric_difference(q)           #common element sodun
# Out:
# {1, 2, 5, 6, 7}

# %%
s = {1,2,3,4,5}
a = frozenset(s)         #used to make set immutable

# %%
dir(s)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
dir(s)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']
