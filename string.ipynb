# %% [markdown]
# # indexing

# %%
a="sumit"
a[3]
# Out:
# 'i'

# %%
a[0]
# Out:
# 's'

# %%
a[-1]
# Out:
# 't'

# %%
type(a)
# Out:
# str

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
a.upper()
# Out:
# 'SUMIT'

# %%
a.lower()
# Out:
# 'sumit'

# %%
a.strip()
# Out:
# 'sumit'

# %%
b="    a,a,s,a,s,a,sa,d,d,d,,f,f    "

# %%
b.lstrip()
# Out:
# 'a,a,s,a,s,a,sa,d,d,d,,f,f    '

# %%
b.rstrip()
# Out:
# '    a,a,s,a,s,a,sa,d,d,d,,f,f'

# %%
b.strip()
# Out:
# 'a,a,s,a,s,a,sa,d,d,d,,f,f'

# %%
type(b)
# Out:
# str

# %%
c="aaannndddhhhh"

# %%
c.count("a")
# Out:
# 3

# %%
c.count("n")
# Out:
# 3

# %% [markdown]
# **reverse string**
# a[::-1]

# %%
a[::-1]
# Out:
# 'timus'

# %%
id(a)         #for memory location checking
# Out:
# 138133941470528

# %%
a.endswith("t")      #end hoto to letter boolean madhe show hoto
# Out:
# True

# %%
a.join("123")
# Out:
# '1sumit2sumit3'

# %%
r=("1234""qwer")

# %%
r.join("12")
# Out:
# '11234qwer2'

# %% [markdown]
# # SLICING

# %% [markdown]
# s=("ITVEDANT")

# %%
s=("ITVEDANT")

# %%
s[0]
# Out:
# 'I'

# %%
s[2]
# Out:
# 'V'

# %%
len(s)
# Out:
# 8

# %%
s[0:7]       # for positive= start:end-1:1
# Out:
# 'ITVEDAN'

# %%
s[2:9]      #in slicing index will not in the string then they willnot print error
# Out:
# 'VEDANT'

# %%
s[0:5:-1]       #this is empty beacuse of we can get negative indexing range will not sastisfied
# Out:
# ''

# %%
s[7:2:-1]
# Out:
# 'TNADE'

# %%
t=("12345678")

# %%
#we can print 456
t[3:6]                  #start:end+1:step is already one will count
# Out:
# '456'

# %%
s[0:8:3]
# Out:
# 'IEN'
